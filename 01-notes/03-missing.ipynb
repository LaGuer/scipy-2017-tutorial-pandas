# %%
# !pip install pandas
# !pip install sklearn
# !pip install matplotlib

# %% [markdown]
# Let's import pandas

# %%
import pandas as pd

# %%
# missing comes from numpy
from numpy import NaN, NAN, nan

# %%
# missing doesnt exqual anything
NaN == True
# Out:
# False

# %%
NAN == True
# Out:
# False

# %%
nan == True
# Out:
# False

# %%
NaN == NaN
# Out:
# False

# %%
# you need a special function to detect missing
pd.isnull(NaN)
# Out:
# True

# %%
pd.notnull(NaN)
# Out:
# False

# %%
pd.notnull(42)
# Out:
# True

# %% [markdown]
# # where does this come from?

# %%
volume = pd.read_csv('https://raw.githubusercontent.com/LaGuer/JupyterDataScienceWorkflow/master/dataset/CRSW-AMIS.csv')

# %%
volume
# Out:
#       Data Source Country/Region Name   Product Name   Element Name  \
# 0             CBS           Argentina  COARSE GRAINS        Exports
# 1             CBS           Argentina  COARSE GRAINS        Exports
# 2             CBS           Argentina  COARSE GRAINS        Exports
# 3             CBS           Argentina  COARSE GRAINS        Exports
# 4             CBS           Argentina  COARSE GRAINS        Exports
# 5             CBS           Argentina  COARSE GRAINS        Exports
# 6             CBS           Argentina  COARSE GRAINS        Exports
# 7             CBS           Argentina  COARSE GRAINS        Exports
# 8             CBS           Argentina  COARSE GRAINS        Exports
# 9             CBS           Argentina  COARSE GRAINS        Exports
# 10            CBS           Argentina  COARSE GRAINS        Exports
# 11            CBS           Argentina  COARSE GRAINS        Exports
# 12            CBS           Argentina  COARSE GRAINS        Exports
# ...

# %%
# you can use the na_values with keep_default_na to manually specify missing

# %%
oecd = pd.read_csv('https://raw.githubusercontent.com/LaGuer/JupyterDataScienceWorkflow/master/dataset/oecd-CRSW-crop-production.csv')

vs = volume.merge(oecd, left_on='Year', right_on='LOCATION')
vs
# Out:
# Empty DataFrame
# Columns: [Data Source, Country/Region Name, Product Name, Element Name, Units, Year, Value_x, LOCATION, INDICATOR, SUBJECT, MEASURE, FREQUENCY, TIME, Value_y, Flag Codes]
# Index: []

# %% [markdown]
# # count missing data

# %%
oecd1 = pd.read_csv('https://raw.githubusercontent.com/LaGuer/JupyterDataScienceWorkflow/master/dataset/oecd-CRSW-crop-production.csv')
oecd2 = pd.read_csv('https://raw.githubusercontent.com/LaGuer/JupyterDataScienceWorkflow/master/dataset/CRSW-AMIS.csv')

# %%
oecd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16240 entries, 0 to 16239
# Data columns (total 8 columns):
# LOCATION      16240 non-null object
# INDICATOR     16240 non-null object
# SUBJECT       16240 non-null object
# MEASURE       16240 non-null object
# FREQUENCY     16240 non-null object
# TIME          16240 non-null int64
# Value         16240 non-null float64
# Flag Codes    0 non-null float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1015.1+ KB

# %%
# sorts by frequency
# will not always be on top
oecd1['SUBJECT'].value_counts(dropna=False).head()
# Out:
# WHEAT      4211
# MAIZE      4101
# SOYBEAN    4021
# RICE       3907
# Name: SUBJECT, dtype: int64

# %% [markdown]
# # Recode missing

# %%
oecd2.head()
# Out:
#   Data Source Country/Region Name   Product Name Element Name           Units  \
# 0         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 1         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 2         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 3         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 4         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
#
#       Year      Value
# 0  2018/19  29.847000
# 1  2017/18  28.733000
# 2  2016/17  25.981412
# 3  2015/16  22.059707
# 4  2014/15  22.675300

# %%
oecd2.fillna(0).head()
# Out:
#   Data Source Country/Region Name   Product Name Element Name           Units  \
# 0         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 1         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 2         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 3         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 4         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
#
#       Year      Value
# 0  2018/19  29.847000
# 1  2017/18  28.733000
# 2  2016/17  25.981412
# 3  2015/16  22.059707
# 4  2014/15  22.675300

# %%
oecd2.fillna(method='ffill').head()
# Out:
#   Data Source Country/Region Name   Product Name Element Name           Units  \
# 0         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 1         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 2         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 3         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 4         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
#
#       Year      Value
# 0  2018/19  29.847000
# 1  2017/18  28.733000
# 2  2016/17  25.981412
# 3  2015/16  22.059707
# 4  2014/15  22.675300

# %%
oecd2.fillna(method='ffill').tail()
# Out:
#       Data Source Country/Region Name Product Name Element Name      Units  \
# 39902         CBS               World        Wheat        Yield  Tonnes/Ha
# 39903         CBS               World        Wheat        Yield  Tonnes/Ha
# 39904         CBS               World        Wheat        Yield  Tonnes/Ha
# 39905         CBS               World        Wheat        Yield  Tonnes/Ha
# 39906         CBS               World        Wheat        Yield  Tonnes/Ha
#
#           Year  Value
# 39902  2004/05  2.892
# 39903  2003/04  2.679
# 39904  2002/03  2.668
# 39905  2001/02  2.734
# 39906  2000/01  2.701

# %%
oecd2.fillna(method='bfill').head()
# Out:
#   Data Source Country/Region Name   Product Name Element Name           Units  \
# 0         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 1         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 2         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 3         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 4         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
#
#       Year      Value
# 0  2018/19  29.847000
# 1  2017/18  28.733000
# 2  2016/17  25.981412
# 3  2015/16  22.059707
# 4  2014/15  22.675300

# %%
oecd2.fillna(method='bfill').tail()
# Out:
#       Data Source Country/Region Name Product Name Element Name      Units  \
# 39902         CBS               World        Wheat        Yield  Tonnes/Ha
# 39903         CBS               World        Wheat        Yield  Tonnes/Ha
# 39904         CBS               World        Wheat        Yield  Tonnes/Ha
# 39905         CBS               World        Wheat        Yield  Tonnes/Ha
# 39906         CBS               World        Wheat        Yield  Tonnes/Ha
#
#           Year  Value
# 39902  2004/05  2.892
# 39903  2003/04  2.679
# 39904  2002/03  2.668
# 39905  2001/02  2.734
# 39906  2000/01  2.701

# %% [markdown]
# # Calculations with missing

# %%
oecd2['Value'].sum()
# Out:
# 227521611.313533

# %%
oecd2['Value'].sum(skipna=False)
# Out:
# 227521611.313533

# %%
oecd1['Value'].sum()
# Out:
# 283424483.17423797

# %%
oecd1['Value'].sum(skipna=False)
# Out:
# 283424483.17423797
