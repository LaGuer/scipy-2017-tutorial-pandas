# %%
# !pip install pandas
# !pip install sklearn
# !pip install matplotlib

# %%
import pandas as pd

# %%
from numpy import NaN, NAN, nan

# %%
nan == True
# Out:
# False

# %%
nan == False
# Out:
# False

# %%
nan == nan
# Out:
# False

# %%
pd.isnull(nan)
# Out:
# True

# %%
pd.isnull(42)
# Out:
# False

# %%
pd.isnull('-')
# Out:
# False

# %%
NaN == nan
# Out:
# False

# %%
#  df1 = pd.read_csv('https://raw.githubusercontent.com/LaGuer/JupyterDataScienceWorkflow/master/dataset/CRSW-AMIS.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/LaGuer/JupyterDataScienceWorkflow/master/dataset/oecd-CRSW-crop-production.csv')
# visited = pd.read_csv('../data/survey_visited.csv')

# %%
visited.columns
# Out:
# Index(['ident', 'site', 'dated'], dtype='object')

# %%
df2.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/LaGuer/JupyterDataScienceWorkflow/master/dataset/CRSW-AMIS.csv')

vs = df2.merge(survey, left_on='LOCATION',
                   right_on='Year')

# %%
vs
# Out:
# Empty DataFrame
# Columns: [LOCATION, INDICATOR, SUBJECT, MEASURE, FREQUENCY, TIME, Value_x, Flag Codes, Data Source, Country/Region Name, Product Name, Element Name, Units, Year, Value_y]
# Index: []

# %%
crsw = pd.read_csv('https://raw.githubusercontent.com/LaGuer/JupyterDataScienceWorkflow/master/dataset/CRSW-AMIS.csv')

# %%
crsw
# Out:
#       Data Source Country/Region Name   Product Name   Element Name  \
# 0             CBS           Argentina  COARSE GRAINS        Exports
# 1             CBS           Argentina  COARSE GRAINS        Exports
# 2             CBS           Argentina  COARSE GRAINS        Exports
# 3             CBS           Argentina  COARSE GRAINS        Exports
# 4             CBS           Argentina  COARSE GRAINS        Exports
# 5             CBS           Argentina  COARSE GRAINS        Exports
# 6             CBS           Argentina  COARSE GRAINS        Exports
# 7             CBS           Argentina  COARSE GRAINS        Exports
# 8             CBS           Argentina  COARSE GRAINS        Exports
# 9             CBS           Argentina  COARSE GRAINS        Exports
# 10            CBS           Argentina  COARSE GRAINS        Exports
# 11            CBS           Argentina  COARSE GRAINS        Exports
# 12            CBS           Argentina  COARSE GRAINS        Exports
# ...

# %%
crsw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39907 entries, 0 to 39906
# Data columns (total 7 columns):
# Data Source            39907 non-null object
# Country/Region Name    39907 non-null object
# Product Name           39907 non-null object
# Element Name           39907 non-null object
# Units                  39907 non-null object
# Year                   39907 non-null object
# Value                  39907 non-null float64
# dtypes: float64(1), object(6)
# memory usage: 2.1+ MB

# %%
# tally
crsw['Value'].value_counts(dropna=False).head()
# Out:
# 0.000    1290
# 0.010     245
# 0.001     217
# 0.500     185
# 0.050     178
# Name: Value, dtype: int64

# %%
# how many unique
crsw['Value'].nunique()
# Out:
# 22303

# %%
# the actual unique values
crsw['Value'].unique()
# Out:
# array([29.847   , 28.733   , 25.981412, ...,  3.43    ,  2.995   ,
#         3.026   ])

# %%
crsw.head()
# Out:
#   Data Source Country/Region Name   Product Name Element Name           Units  \
# 0         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 1         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 2         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 3         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 4         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
#
#       Year      Value
# 0  2018/19  29.847000
# 1  2017/18  28.733000
# 2  2016/17  25.981412
# 3  2015/16  22.059707
# 4  2014/15  22.675300

# %%
crsw.fillna(0)
# Out:
#       Data Source Country/Region Name   Product Name   Element Name  \
# 0             CBS           Argentina  COARSE GRAINS        Exports
# 1             CBS           Argentina  COARSE GRAINS        Exports
# 2             CBS           Argentina  COARSE GRAINS        Exports
# 3             CBS           Argentina  COARSE GRAINS        Exports
# 4             CBS           Argentina  COARSE GRAINS        Exports
# 5             CBS           Argentina  COARSE GRAINS        Exports
# 6             CBS           Argentina  COARSE GRAINS        Exports
# 7             CBS           Argentina  COARSE GRAINS        Exports
# 8             CBS           Argentina  COARSE GRAINS        Exports
# 9             CBS           Argentina  COARSE GRAINS        Exports
# 10            CBS           Argentina  COARSE GRAINS        Exports
# 11            CBS           Argentina  COARSE GRAINS        Exports
# 12            CBS           Argentina  COARSE GRAINS        Exports
# ...

# %%
crsw.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
crsw.fillna(method='ffill').head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286        2769.0         8157.0             9722.0
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
crsw.fillna(method='bfill').head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0         8166.0            10030.0
# 1    1/4/2015  288        2775.0         8166.0             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286        2730.0         8157.0             9633.0
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0           20.0            1.0                 4.0          1.0         7.0
# 1           20.0            1.0                 4.0          1.0         7.0
# 2           20.0            1.0                 4.0          1.0         7.0
# 3           20.0            1.0                 4.0          1.0         7.0
# 4           20.0            1.0                 4.0          1.0         7.0
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
crsw.head()
# Out:
#   Data Source Country/Region Name   Product Name Element Name           Units  \
# 0         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 1         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 2         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 3         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
# 4         CBS           Argentina  COARSE GRAINS      Exports  Million tonnes
#
#       Year      Value
# 0  2018/19  29.847000
# 1  2017/18  28.733000
# 2  2016/17  25.981412
# 3  2015/16  22.059707
# 4  2014/15  22.675300

# %%
crsw['Value'].sum()
# Out:
# 227521611.313533

# %%
crsw['Value'].sum(skipna=False)
# Out:
# 227521611.313533

# %%
df = pd.DataFrame({
    'a': [1, 2, 88, 99],
    'b': [3, NaN, 999, NaN]
})
df
# Out:
#     a      b
# 0   1    3.0
# 1   2    NaN
# 2  88  999.0
# 3  99    NaN

# %%
df.replace(to_replace=[88, 99, 999], value=NaN)
# Out:
#      a    b
# 0  1.0  3.0
# 1  2.0  NaN
# 2  NaN  NaN
# 3  NaN  NaN
